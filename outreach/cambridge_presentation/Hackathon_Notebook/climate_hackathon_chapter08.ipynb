# %% [markdown]
# <a href="https://colab.research.google.com/github/petermr/semanticClimate/blob/main/outreach/cambridge_presentation/Hackathon_Notebook/climate_hackathon_chapter08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***For newcomers:***
#
# This is a Jupyter-like Notebook, running in a browser. No need to install anything else on your local machine. All installed software is on the remote machine.
#
#  **Cells** can be `text` (like this one) or `code` that can be executed (by clicking a `[ ]` symbol in top-left of cell). Cells need executing in order and will have a green tick when completed.
#
# Software will be installed automatically by the first `code` button below. You don't have to think, but it will take about 4 minutes. You don't need to repeat unless you log out.

# %% [markdown]
# **Content**:
# these cells have been developed to run Chapters 02, 07 and 08 of IPCC AR6 WG3. Cells relate to Chapter 08, but can be edited manually to process Chapters 02 or 07.

# %% [markdown]
# ##Install packages
# ![image.png](data:image/png;base64,...)
# **To install packages run the cell below... This may take 4 min or so**
#
#
# ---
# <hr height=3>

# %% [markdown]
# To run a cell please follow these instructions.
# Toggle your cursor near empty square brackets on the left top corner of each cell or Click the play button once your cursor is on the empty square brackets

# %%
#installing the tools
# !git clone  https://github.com/petermr/semanticClimate.git
# !pip install -r /content/semanticClimate/keyword_extraction/code/requirement.txt
# !pip install docanalysis
# !pip install py4ami==0.0.35
# !python -m spacy download en_core_web_lg
import nltk
nltk.download('stopwords')
# Out:
# fatal: destination path 'semanticClimate' already exists and is not an empty directory.
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting git+https://github.com/LIAAD/yake (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2))
#   Cloning https://github.com/LIAAD/yake to /tmp/pip-req-build-pob71j1e
#   Running command git clone -q https://github.com/LIAAD/yake /tmp/pip-req-build-pob71j1e
# Requirement already satisfied: multi_rake in /usr/local/lib/python3.7/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1)) (0.0.2)
# Requirement already satisfied: summa in /usr/local/lib/python3.7/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 3)) (1.2.0)
# Requirement already satisfied: keybert in /usr/local/lib/python3.7/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5)) (1.3.4)
# Requirement already satisfied: tkinterhtml==0.7 in /usr/local/lib/python3.7/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 6)) (0.7)
# Requirement already satisfied: pyamiimage in /usr/local/lib/python3.7/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.0.13)
# Requirement already satisfied: pdfplumber==0.7.4 in /usr/local/lib/python3.7/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (0.7.4)
# Requirement already satisfied: pdfminer3 in /usr/local/lib/python3.7/dist-packages (from -r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 9)) (2018.12.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (0.8.10)
# Requirement already satisfied: click>=6.0 in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (7.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (1.21.6)
# Requirement already satisfied: segtok in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (1.5.11)
# Requirement already satisfied: networkx in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (2.6.3)
# Requirement already satisfied: jellyfish in /usr/local/lib/python3.7/dist-packages (from yake==0.4.8->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 2)) (0.9.0)
# Requirement already satisfied: pdfminer.six==20220524 in /usr/local/lib/python3.7/dist-packages (from pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (20220524)
# Requirement already satisfied: Pillow>=9.1 in /usr/local/lib/python3.7/dist-packages (from pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (9.2.0)
# Requirement already satisfied: Wand>=0.6.7 in /usr/local/lib/python3.7/dist-packages (from pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (0.6.10)
# Requirement already satisfied: cryptography>=36.0.0 in /usr/local/lib/python3.7/dist-packages (from pdfminer.six==20220524->pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (38.0.1)
# Requirement already satisfied: charset-normalizer>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from pdfminer.six==20220524->pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (2.1.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.7/dist-packages (from cryptography>=36.0.0->pdfminer.six==20220524->pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.12->cryptography>=36.0.0->pdfminer.six==20220524->pdfplumber==0.7.4->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 8)) (2.21)
# Requirement already satisfied: pycld2>=0.41 in /usr/local/lib/python3.7/dist-packages (from multi_rake->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1)) (0.41)
# Requirement already satisfied: regex>=2018.6.6 in /usr/local/lib/python3.7/dist-packages (from multi_rake->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1)) (2022.6.2)
# Requirement already satisfied: pyrsistent>=0.14.2 in /usr/local/lib/python3.7/dist-packages (from multi_rake->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 1)) (0.18.1)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.7/dist-packages (from summa->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 3)) (1.7.3)
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.7/dist-packages (from keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.0.2)
# Requirement already satisfied: sentence-transformers>=0.3.8 in /usr/local/lib/python3.7/dist-packages (from keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.2.2)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.7/dist-packages (from keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (12.6.0)
# Collecting typing-extensions<5.0,>=4.0.0
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.4.0->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.13.0)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /usr/local/lib/python3.7/dist-packages (from rich>=10.4.0->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.9.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.22.2->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.2.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (4.62.3)
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (4.23.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.6.7)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.13.1+cu113)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.12.1+cu113)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.10.1)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.1.97)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.23.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (5.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.8.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.0.9)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /usr/local/lib/python3.7/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (0.13.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5)) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5)) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 5)) (1.15.0)
# Requirement already satisfied: skan in /usr/local/lib/python3.7/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.10.0)
# Requirement already satisfied: pytesseract in /usr/local/lib/python3.7/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.3.10)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (3.2.2)
# Requirement already satisfied: easyocr in /usr/local/lib/python3.7/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.6.2)
# Requirement already satisfied: sknw in /usr/local/lib/python3.7/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.14)
# Requirement already satisfied: pytest in /usr/local/lib/python3.7/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (6.2.5)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.7/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.18.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (60.3.1)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (4.7.1)
# Requirement already satisfied: chardet in /usr/local/lib/python3.7/dist-packages (from pdfminer3->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 9)) (3.0.4)
# Requirement already satisfied: sortedcontainers in /usr/local/lib/python3.7/dist-packages (from pdfminer3->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 9)) (2.4.0)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.7/dist-packages (from pdfminer3->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 9)) (3.15.0)
# Requirement already satisfied: ninja in /usr/local/lib/python3.7/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.10.2.4)
# Requirement already satisfied: pyclipper in /usr/local/lib/python3.7/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.3.0.post3)
# Requirement already satisfied: python-bidi in /usr/local/lib/python3.7/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.4.2)
# Requirement already satisfied: opencv-python-headless<=4.5.4.60 in /usr/local/lib/python3.7/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (4.5.4.60)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.7/dist-packages (from easyocr->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.8.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (3.9.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.4.4)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.11.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.0.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.7/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.1.1)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.10.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from pytest->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (22.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.3.8->keybert->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 4)) (2.10)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from scikit-image->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.3.0)
# Requirement already satisfied: imageio>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from scikit-image->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2.9.0)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.7/dist-packages (from scikit-image->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2021.11.2)
# Requirement already satisfied: openpyxl>=2.4 in /usr/local/lib/python3.7/dist-packages (from skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (3.0.10)
# Requirement already satisfied: numba>=0.50 in /usr/local/lib/python3.7/dist-packages (from skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.56.2)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.7/dist-packages (from skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.12.0)
# Requirement already satisfied: numpydoc>=0.9.2 in /usr/local/lib/python3.7/dist-packages (from skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.5.0)
# Collecting setuptools
#   Downloading setuptools-59.8.0-py3-none-any.whl (952 kB)
#      |████████████████████████████████| 952 kB 12.9 MB/s
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.50->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.39.1)
# Requirement already satisfied: Jinja2>=2.10 in /usr/local/lib/python3.7/dist-packages (from numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (3.1.2)
# Requirement already satisfied: sphinx>=4.2 in /usr/local/lib/python3.7/dist-packages (from numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (5.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from Jinja2>=2.10->numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2.0.1)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl>=2.4->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.1.0)
# Requirement already satisfied: sphinxcontrib-devhelp in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.0.2)
# Requirement already satisfied: snowballstemmer>=2.0 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2.2.0)
# Requirement already satisfied: alabaster<0.8,>=0.7 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.7.12)
# Requirement already satisfied: sphinxcontrib-jsmath in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.0.3)
# Requirement already satisfied: docutils<0.20,>=0.14 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (0.17.1)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.4.1)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.5 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.1.5)
# Requirement already satisfied: babel>=2.9 in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (2.10.3)
# Requirement already satisfied: sphinxcontrib-applehelp in /usr/local/lib/python3.7/dist-packages (from sphinx>=4.2->numpydoc>=0.9.2->skan->pyamiimage->-r /content/semanticClimate/keyword_extraction/code/requirement.txt (line 7)) (1.0.2)
# Installing collected packages: typing-extensions, setuptools
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.10.0.2
#     Uninstalling typing-extensions-3.10.0.2:
#       Successfully uninstalled typing-extensions-3.10.0.2
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 60.3.1
#     Uninstalling setuptools-60.3.1:
#       Successfully uninstalled setuptools-60.3.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# thinc 8.0.17 requires typing-extensions<4.2.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.
# spacy 3.0.7 requires typing-extensions<4.0.0.0,>=3.7.4; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.
# en-core-web-sm 3.4.0 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.0.7 which is incompatible.
# docanalysis 0.2.0 requires setuptools==60.3.1, but you have setuptools 59.8.0 which is incompatible.
# confection 0.0.3 requires typing-extensions<4.2.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.
# Successfully installed setuptools-59.8.0 typing-extensions-4.4.0
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: docanalysis in /usr/local/lib/python3.7/dist-packages (0.2.0)
# Requirement already satisfied: pandas==1.3.4 in /usr/local/lib/python3.7/dist-packages (from docanalysis) (1.3.4)
# Requirement already satisfied: tqdm==4.62.3 in /usr/local/lib/python3.7/dist-packages (from docanalysis) (4.62.3)
# Requirement already satisfied: spacy==3.0.7 in /usr/local/lib/python3.7/dist-packages (from docanalysis) (3.0.7)
# Requirement already satisfied: lxml==4.7.1 in /usr/local/lib/python3.7/dist-packages (from docanalysis) (4.7.1)
# Requirement already satisfied: nltk==3.6.7 in /usr/local/lib/python3.7/dist-packages (from docanalysis) (3.6.7)
# Requirement already satisfied: abbreviations in /usr/local/lib/python3.7/dist-packages (from docanalysis) (0.2.5)
# Requirement already satisfied: braceexpand==0.1.7 in /usr/local/lib/python3.7/dist-packages (from docanalysis) (0.1.7)
# Requirement already satisfied: py4ami in /usr/local/lib/python3.7/dist-packages (from docanalysis) (0.0.35)
# Requirement already satisfied: tkinterweb==3.10.7 in /usr/local/lib/python3.7/dist-packages (from docanalysis) (3.10.7)
# Requirement already satisfied: pygetpapers in /usr/local/lib/python3.7/dist-packages (from docanalysis) (1.2.3)
# Collecting setuptools==60.3.1
#   Using cached setuptools-60.3.1-py3-none-any.whl (953 kB)
# Requirement already satisfied: ConfigArgParse==1.5.3 in /usr/local/lib/python3.7/dist-packages (from docanalysis) (1.5.3)
# Requirement already satisfied: scispacy==0.4.0 in /usr/local/lib/python3.7/dist-packages (from docanalysis) (0.4.0)
# Requirement already satisfied: coloredlogs==15.0.1 in /usr/local/lib/python3.7/dist-packages (from docanalysis) (15.0.1)
# Requirement already satisfied: pytest==6.2.5 in /usr/local/lib/python3.7/dist-packages (from docanalysis) (6.2.5)
# Requirement already satisfied: beautifulsoup4==4.10.0 in /usr/local/lib/python3.7/dist-packages (from docanalysis) (4.10.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.7/dist-packages (from beautifulsoup4==4.10.0->docanalysis) (2.3.2.post1)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/lib/python3.7/dist-packages (from coloredlogs==15.0.1->docanalysis) (10.0)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from nltk==3.6.7->docanalysis) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from nltk==3.6.7->docanalysis) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.7/dist-packages (from nltk==3.6.7->docanalysis) (2022.6.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.4->docanalysis) (2022.4)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.4->docanalysis) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas==1.3.4->docanalysis) (1.21.6)
# Requirement already satisfied: importlib-metadata>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.5->docanalysis) (5.0.0)
# Requirement already satisfied: iniconfig in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.5->docanalysis) (1.1.1)
# Requirement already satisfied: py>=1.8.2 in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.5->docanalysis) (1.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.5->docanalysis) (21.3)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.5->docanalysis) (1.0.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.5->docanalysis) (0.10.2)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.7/dist-packages (from pytest==6.2.5->docanalysis) (22.1.0)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (0.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (3.1.2)
# Collecting typing-extensions<4.0.0.0,>=3.7.4
#   Using cached typing_extensions-3.10.0.2-py3-none-any.whl (26 kB)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (1.0.8)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (3.0.10)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (0.7.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (2.0.8)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (2.0.6)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (2.4.4)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (0.10.1)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (8.0.17)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (2.23.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (1.8.2)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (0.6.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy==3.0.7->docanalysis) (3.0.7)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from tkinterweb==3.10.7->docanalysis) (9.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy==3.0.7->docanalysis) (3.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytest==6.2.5->docanalysis) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy==3.0.7->docanalysis) (5.2.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas==1.3.4->docanalysis) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.7->docanalysis) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.7->docanalysis) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.7->docanalysis) (2022.9.24)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy==3.0.7->docanalysis) (1.24.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy==3.0.7->docanalysis) (2.0.1)
# Requirement already satisfied: xmltodict in /usr/local/lib/python3.7/dist-packages (from pygetpapers->docanalysis) (0.13.0)
# Requirement already satisfied: habanero in /usr/local/lib/python3.7/dist-packages (from pygetpapers->docanalysis) (1.2.2)
# Requirement already satisfied: arxiv in /usr/local/lib/python3.7/dist-packages (from pygetpapers->docanalysis) (1.4.2)
# Requirement already satisfied: dict2xml in /usr/local/lib/python3.7/dist-packages (from pygetpapers->docanalysis) (1.7.2)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.7/dist-packages (from arxiv->pygetpapers->docanalysis) (6.0.10)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.7/dist-packages (from feedparser->arxiv->pygetpapers->docanalysis) (1.0.0)
# Requirement already satisfied: pysbd in /usr/local/lib/python3.7/dist-packages (from scispacy==0.4.0->docanalysis) (0.3.4)
# Requirement already satisfied: scikit-learn>=0.20.3 in /usr/local/lib/python3.7/dist-packages (from scispacy==0.4.0->docanalysis) (1.0.2)
# Requirement already satisfied: nmslib>=1.7.3.6 in /usr/local/lib/python3.7/dist-packages (from scispacy==0.4.0->docanalysis) (2.1.1)
# Requirement already satisfied: conllu in /usr/local/lib/python3.7/dist-packages (from scispacy==0.4.0->docanalysis) (4.5.2)
# Requirement already satisfied: pybind11<2.6.2 in /usr/local/lib/python3.7/dist-packages (from nmslib>=1.7.3.6->scispacy==0.4.0->docanalysis) (2.6.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from nmslib>=1.7.3.6->scispacy==0.4.0->docanalysis) (5.4.8)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.3->scispacy==0.4.0->docanalysis) (3.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.20.3->scispacy==0.4.0->docanalysis) (1.7.3)
# Installing collected packages: typing-extensions, setuptools
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.4.0
#     Uninstalling typing-extensions-4.4.0:
#       Successfully uninstalled typing-extensions-4.4.0
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 59.8.0
#     Uninstalling setuptools-59.8.0:
#       Successfully uninstalled setuptools-59.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# rich 12.6.0 requires typing-extensions<5.0,>=4.0.0; python_version < "3.9", but you have typing-extensions 3.10.0.2 which is incompatible.
# numba 0.56.2 requires setuptools<60, but you have setuptools 60.3.1 which is incompatible.
# en-core-web-sm 3.4.0 requires spacy<3.5.0,>=3.4.0, but you have spacy 3.0.7 which is incompatible.
# Successfully installed setuptools-60.3.1 typing-extensions-3.10.0.2
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: py4ami==0.0.35 in /usr/local/lib/python3.7/dist-packages (0.0.35)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting en-core-web-lg==3.0.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.0.0/en_core_web_lg-3.0.0-py3-none-any.whl (778.8 MB)
#      |████████████████████████████████| 778.8 MB 18 kB/s
# Requirement already satisfied: spacy<3.1.0,>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from en-core-web-lg==3.0.0) (3.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.21.6)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.8.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.3.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.7)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (4.62.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (21.3)
# Requirement already satisfied: pathy>=0.3.5 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.6.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.10.1)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (0.7.8)
# Requirement already satisfied: thinc<8.1.0,>=8.0.3 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (8.0.17)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.6)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.1.2)
# Requirement already satisfied: typing-extensions<4.0.0.0,>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.10.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (60.3.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.23.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.0.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.8)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /usr/local/lib/python3.7/dist-packages (from spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.4.4)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from catalogue<2.1.0,>=2.0.4->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.9.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.9)
# Requirement already satisfied: smart-open<6.0.0,>=5.2.1 in /usr/local/lib/python3.7/dist-packages (from pathy>=0.3.5->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (5.2.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2022.9.24)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /usr/local/lib/python3.7/dist-packages (from typer<0.4.0,>=0.3.0->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.7/dist-packages (from jinja2->spacy<3.1.0,>=3.0.0->en-core-web-lg==3.0.0) (2.0.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ***Please don't forget to restart runtime after running the previous cell, else the newly installed packages won't run properly***
#
# Also, Once the cell finishes running you can see a green tick along with the number in place of square bracket stating the order in which cells are run and giving information on successful completion of the job.

# %% [markdown]
# You can find the html files of respective interest here: **/content/semanticClimate/ipcc/ar6/wg3/Chapter08/fulltext.html**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Abbreviations extraction
#
# ![image.png](data:image/png;base64,...)
# **To extract abbreviation, just run the cell below by taking your cursor over the empty square bracket at the left top corner of the cell below...It takes a min or so...**

# %%
#making directory to store and obtain the dictionaries 
import os
import shutil
chapter_no ='Chapter08'
saving_path = f'/content/wiki_hack/{chapter_no}/sections/0_mainbody/'
if not os.path.exists(saving_path):
  os.makedirs(saving_path)
shutil.copy(f'/content/semanticClimate/ipcc/ar6/wg3/{chapter_no}/fulltext.html',f'/content/wiki_hack/{chapter_no}/sections/0_mainbody')

print('\033[1;32m We have successfully finished running this cell.')
# Out:
#  We have successfully finished running this cell.

# %%
#abbreviation extraction --automated abbreviation using docanalysis
# !docanalysis --project_name '/content/wiki_hack' --output 'entities.csv' --make_ami_dict 'entities.xml'
# structuring the dictionary
# !docanalysis --project_name '/content/wiki_hack'\
--output 'Indexing.csv' --make_json 'Indexing.json'\
--make_ami_dict 'entities' --extract_abb 'abb_chapter08'

print('\033[1;32m We have successfully finished running this cell.')
# Out:
# /usr/local/lib/python3.7/dist-packages/_distutils_hack/__init__.py:36: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100% 1/1 [00:00<00:00,  1.45it/s]
# INFO: Found 2091 sentences in the section(s).
# /usr/local/lib/python3.7/dist-packages/docanalysis/entity_extraction.py:687: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   "[", "").str.replace("]", "")
# INFO: wrote output to /content/wiki_hack/entities.csv
# INFO: Wrote all the entities extracted to /content/wiki_hack/entities.xml.xml
# /usr/local/lib/python3.7/dist-packages/_distutils_hack/__init__.py:36: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100% 1/1 [00:00<00:00,  2.08it/s]
# INFO: Found 2091 sentences in the section(s).
# 22it [00:03,  6.01it/s]
# INFO: wrote all abbreviations to ami dict /content/wiki_hack/abb_chapter08.xml
# /usr/local/lib/python3.7/dist-packages/docanalysis/entity_extraction.py:687: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   "[", "").str.replace("]", "")
# INFO: wrote output to /content/wiki_hack/Indexing.csv
# INFO: wrote JSON output to /content/wiki_hack/Indexing.json
# INFO: Wrote all the entities extracted to /content/wiki_hack/entities.xml
#  We have successfully finished running this cell.

# %% [markdown]
# You can find the output of abbreviation extraction here: **/content/wiki_hack/abb_chapter08.xml**
#
# You can't see the file within colab enviornmnet. Therefore follow the path and download the file and open in your respective system.
#
# Follow this picture to understand how to download a file.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Keywords/ Key-Phrases Extraction
#
# ![image.png](data:image/png;base64,...)
# **To get keywords and key-phrases extracted run the cell below...It take a min or two......**

# %%
# keyword/ phrases extraction
# !python /content/semanticClimate/keyword_extraction/code/keyword_extraction.py \
--html_path /content/semanticClimate/ipcc/ar6/wg3/Chapter08/fulltext.html \
--saving_path /content/ \
--method 'gensim'
print('\033[1;32m We have successfully finished running this cell.')
# Out:
#  We have successfully finished running this cell.

# %% [markdown]
# You can find the output of Keyword/key-phrases extraction here: **/content/gensim_keywords.csv**

# %% [markdown]
# A demonstration on how to look into CSV/HTML files on your right side of the notebbok:
#
# ![image.png](data:image/png;base64,...)

# %%
# WordCloud Generation
# !python /content/semanticClimate/wordCloud_Generation/SemanticClimate_wordcloud.py\
--file_path '/content/semanticClimate/wordCloud_Generation/'\
--saving_path '/content/'\
--Chapter_name 'Chapter08'

import cv2
from PIL import Image
from google.colab.patches import cv2_imshow
img = cv2.imread(f'/content/{chapter_no}_word_cloud.jpg', cv2.IMREAD_COLOR)
cv2_imshow(img)


#print('\033[1;32m We have successfully finished running this cell.')
# Out:
# Figure(1300x900)
# <PIL.Image.Image image mode=RGB size=1541x785>

# %% [markdown]
# ##HTML Markup and Annotation
# ![image.png](data:image/png;base64,...)
# **To Markup the HTML please click on the cell bellow..This also takes a min to run...**

# %%
# HTM markup using abbreviation dictionary + manual dictionary + keyword/phrases 
# !py4ami HTML --annotate\
--dict /content/wiki_hack/abb_chapter08.xml\
--inpath /content/semanticClimate/ipcc/ar6/wg3/Chapter08/fulltext.html\
--outpath /content/annotated_fulltext_Chapter08.html\
--color YELLOW

print('\033[1;32m We have successfully finished running this cell.')
# Out:
# ===========LOGGING 30 .. 10
# WARNING:pyami:
# ============== running pyami main ===============
# ['HTML', '--annotate', '--dict', '/content/wiki_hack/abb_chapter08.xml', '--inpath', '/content/semanticClimate/ipcc/ar6/wg3/Chapter08/fulltext.html', '--outpath', '/content/annotated_fulltext_Chapter08.html', '--color', 'YELLOW']
# WARNING:symbol.ini: environment variable $PYAMI_HOME not set, defaulting to bundled config.ini in /usr/local/lib/python3.7/dist-packages/py4ami
# WARNING:pyami:********** raw arglist ['HTML', '--annotate', '--dict', '/content/wiki_hack/abb_chapter08.xml', '--inpath', '/content/semanticClimate/ipcc/ar6/wg3/Chapter08/fulltext.html', '--outpath', '/content/annotated_fulltext_Chapter08.html', '--color', 'YELLOW']
# WARNING:pyami:PARSED_ARGS Namespace(annotate=True, apply=None, assert=None, color=['YELLOW'], combine=None, command='HTML', config=None, copy=None, debug=None, delete=None, dict=['/content/wiki_hack/abb_chapter08.xml'], examples=None, filter=None, flags=None, glob=None, inpath=['/content/semanticClimate/ipcc/ar6/wg3/Chapter08/fulltext.html'], languages=['en'], loglevel='info', maxbars=25, nosearch=False, outdir=None, outfile=None, outpath=['/content/annotated_fulltext_Chapter08.html'], patt=None, plot=True, proj=None, sect=None, split=None, version=False)
# WARNING:pyami:ARGS after substitution: {'version': False, 'apply': None, 'assert': None, 'combine': None, 'config': None, 'copy': None, 'debug': None, 'delete': None, 'dict': '/content/wiki_hack/abb_chapter08.xml', 'examples': None, 'filter': None, 'flags': None, 'glob': None, 'languages': 'en', 'loglevel': 'info', 'maxbars': 25, 'nosearch': False, 'outfile': None, 'patt': None, 'plot': True, 'proj': None, 'sect': None, 'split': None, 'command': 'HTML', 'annotate': True, 'color': 'YELLOW', 'inpath': '/content/semanticClimate/ipcc/ar6/wg3/Chapter08/fulltext.html', 'outpath': '/content/annotated_fulltext_Chapter08.html', 'outdir': None}
#  COMMAND: HTML {'version': False, 'apply': None, 'assert': None, 'combine': None, 'config': None, 'copy': None, 'debug': None, 'delete': None, 'dict': '/content/wiki_hack/abb_chapter08.xml', 'examples': None, 'filter': None, 'flags': None, 'glob': None, 'languages': 'en', 'loglevel': 'info', 'maxbars': 25, 'nosearch': False, 'outfile': None, 'patt': None, 'plot': True, 'proj': None, 'sect': None, 'split': None, 'command': 'HTML', 'annotate': True, 'color': 'YELLOW', 'inpath': '/content/semanticClimate/ipcc/ar6/wg3/Chapter08/fulltext.html', 'outpath': '/content/annotated_fulltext_Chapter08.html', 'outdir': None}
# WARNING:root:********** args for parse_and_process1 {'version': False, 'apply': None, 'assert': None, 'combine': None, 'config': None, 'copy': None, 'debug': None, 'delete': None, 'dict': '/content/wiki_hack/abb_chapter08.xml', 'examples': None, 'filter': None, 'flags': None, 'glob': None, 'languages': 'en', 'loglevel': 'info', 'maxbars': 25, 'nosearch': False, 'outfile': None, 'patt': None, 'plot': True, 'proj': None, 'sect': None, 'split': None, 'command': 'HTML', 'annotate': True, 'color': 'YELLOW', 'inpath': '/content/semanticClimate/ipcc/ar6/wg3/Chapter08/fulltext.html', 'outpath': '/content/annotated_fulltext_Chapter08.html', 'outdir': None}
# dictfile /content/wiki_hack/abb_chapter08.xml
# dictionary.entries 22
# duplicate terms not allowed greenhouse  gas
# duplicate terms not allowed urban heat island
# duplicate terms not allowed illustrative mitigation pathways
# entry_by_term 19
# title abb_chapter08
#  a_elems 108
# match_counter Counter({'United States': 21, 'New York City': 8, 'urban heat island': 2, 'Illustrative Mitigation Pathways': 2, 'Greenhouse  Gas': 1, 'Intergovernmental Panel on Climate Change': 1, 'greenhouse  gas': 1, 'Special Report on Climate Change and Land': 1, 'Intergovernmental Science-Policy Platform on Biodiversity and Ecosystem Services': 1, 'New  Urban  Agenda': 1, 'Global  Covenant  of  Mayors': 1, 'Representative Concentration Pathway': 1, 'Least-Developed Countries': 1, 'gross domestic product': 1, 'in the transformation pathways for renewable energy': 1, 'glue-laminated': 1, 'cross-laminated timber': 1, 'International Cooperative Initiatives': 1, 'UN Environment Programme’s': 1})
# multidict {'United States': ['id171_1', 'id175_1', 'id175_4', 'id181_1', 'id181_4', 'id181_7', 'id181_10', 'id181_13', 'id181_16', 'id181_19', 'id199_1', 'id4347_1', 'id4347_4', 'id5910_1', 'id5910_4', 'id7012_1', 'id12792_4', 'id14831_1', 'id14842_1', 'id17627_1', 'id17641_1'], 'Greenhouse  Gas': ['id929_1'], 'urban heat island': ['id1361_1', 'id4318_1'], 'Intergovernmental Panel on Climate Change': ['id1632_1'], 'greenhouse  gas': ['id1632_4'], 'Special Report on Climate Change and Land': ['id1656_1'], 'Intergovernmental Science-Policy Platform on Biodiversity and Ecosystem Services': ['id1666_1'], 'New  Urban  Agenda': ['id1676_1'], 'Global  Covenant  of  Mayors': ['id1860_1'], 'Representative Concentration Pathway': ['id1894_1'], 'Least-Developed Countries': ['id2365_1'], 'gross domestic product': ['id4010_1'], 'Illustrative Mitigation Pathways': ['id9267_1', 'id9487_1'], 'in the transformation pathways for renewable energy': ['id9267_4'], 'glue-laminated': ['id11747_1'], 'cross-laminated timber': ['id11747_4'], 'New York City': ['id12492_1', 'id12501_1', 'id12501_4', 'id12516_1', 'id12521_1', 'id12526_1', 'id12535_1', 'id12792_1'], 'International Cooperative Initiatives': ['id14486_1'], 'UN Environment Programme’s': ['id14821_1']}
# wrote /content/annotated_fulltext_Chapter08.html
# wrote /content/index.html
#  We have successfully finished running this cell.

# %% [markdown]
# You can find the ouput of HTML Markup and annotation chuck here: **/content/annotated_fulltext_Chapter08.html**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Conversion ---> pdf to html
#
# We are working on building pdf to html conversion tool, which is called as pyami pdf conversion tool...we will demonstrate it in our next hackathon
