# %% [markdown]
# <a href="https://colab.research.google.com/github/petermr/semanticClimate/blob/main/outreach/climate_knowledge_hunt_hackathon/Hackathon_Notebook/climate_hackathon_chapter07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Install packages
# ![image.png](data:image/png;base64,...)
# **To install packages run the cell below... This may take 4 min or so**
#
#
# ---
# <hr height=3>

# %% [markdown]
# To run a cell please follow this figure. Mainly you have to click the play button....
#
#
# ![image.png](data:image/png;base64,...)

# %%
#installing the tools
# !git clone  https://github.com/petermr/semanticClimate.git
# !pip install -r /content/semanticClimate/keyword_extraction/code/requirement.txt
# !pip install docanalysis
# !pip install py4ami==0.0.35
# !python -m spacy download en_core_web_lg
import nltk
nltk.download('stopwords')

# %% [markdown]
# ***Please Dont forget to restart runtime after running the previous cell, else the newly installed packages won't run properly***

# %% [markdown]
# ## Conversion ---> pdf to html

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# **In order to unlock a pdf into an HTML, you just have to click on the cell run below...This takes less than a min to run...**

# %%
import os
import shutil

chapter_no ='Chapter07'
saving_path_html = f'/content/Pdf_to_html_{chapter_no}/'
if not os.path.exists(saving_path_html+'final/'):
  os.makedirs(saving_path_html+'final/')
if not os.path.exists(saving_path_html+'temp/'):
  os.makedirs(saving_path_html+'temp/')  

print('\033[1;32m We have successfully finished running this cell.')
# Out:
#  We have successfully finished running this cell.

# %%
# pdf to html conversion
# !py4ami PDF\
--inpath '/content/semanticClimate/ipcc/ar6/wg3/Chapter07/fulltext.pdf'\
--outpath '/content/Pdf_to_html_Chapter07/final/fulltext.html'\
--outdir  '/content/Pdf_to_html_Chapter07/temp/'\
--pages 1_11

print('\033[1;32m We have successfully finished running this cell.')

# %% [markdown]
# You can find the output here: **/content/semanticClimate/ipcc/ar6/wg3/Chapter07/fulltext.html**
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Abbreviations extraction
#
# ![image.png](data:image/png;base64,...)
# **To extract abbreviation, just run the cell below...It takes a min or so...**

# %%
#making directory to store and obtain the dictionaries 
saving_path = f'/content/wiki_hack/{chapter_no}/sections/0_mainbody/'
if not os.path.exists(saving_path):
  os.makedirs(saving_path)
shutil.copy(f'/content/semanticClimate/ipcc/ar6/wg3/{chapter_no}/fulltext.html',f'/content/wiki_hack/{chapter_no}/sections/0_mainbody')

print('\033[1;32m We have successfully finished running this cell.')
# Out:
#  We have successfully finished running this cell.

# %%
#abbreviation extraction --automated abbreviation using docanalysis
# !docanalysis --project_name '/content/wiki_hack' --output 'entities.csv' --make_ami_dict 'entities.xml'
# structuring the dictionary
# !docanalysis --project_name '/content/wiki_hack'\
--output 'Indexing.csv' --make_json 'Indexing.json'\
--make_ami_dict 'entities' --extract_abb 'abb_chapter07'

print('\033[1;32m We have successfully finished running this cell.')
# Out:
# /usr/local/lib/python3.7/dist-packages/_distutils_hack/__init__.py:36: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100% 1/1 [00:01<00:00,  1.25s/it]
# INFO: Found 3703 sentences in the section(s).
# /usr/local/lib/python3.7/dist-packages/docanalysis/entity_extraction.py:687: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   "[", "").str.replace("]", "")
# INFO: wrote output to /content/wiki_hack/entities.csv
# INFO: Wrote all the entities extracted to /content/wiki_hack/entities.xml.xml
# /usr/local/lib/python3.7/dist-packages/_distutils_hack/__init__.py:36: UserWarning: Setuptools is replacing distutils.
#   warnings.warn("Setuptools is replacing distutils.")
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 100% 1/1 [00:01<00:00,  1.05s/it]
# INFO: Found 3703 sentences in the section(s).
# 70it [00:30,  2.26it/s]
# INFO: wrote all abbreviations to ami dict /content/wiki_hack/abb_chapter07.xml
# /usr/local/lib/python3.7/dist-packages/docanalysis/entity_extraction.py:687: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   "[", "").str.replace("]", "")
# INFO: wrote output to /content/wiki_hack/Indexing.csv
# INFO: wrote JSON output to /content/wiki_hack/Indexing.json
# INFO: Wrote all the entities extracted to /content/wiki_hack/entities.xml
#  We have successfully finished running this cell.

# %% [markdown]
# You can find the output of abbreviation extraction here: **/content/wiki_hack/abb_chapter07.xml**
#
# You can't see the file within colab enviornmnet. Therefore follow th epath and download the file and open in your respective system.
#
# Follow this picture to understand how to download a file.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ##Keywords/ Key-Phrases Extraction
#
# ![image.png](data:image/png;base64,...)
# **To get keywords and key-phrases extracted run the cell below...It take a min or two......**

# %%
# keyword/ phrases extraction
# !python /content/semanticClimate/keyword_extraction/code/keyword_extraction.py \
--html_path /content/semanticClimate/ipcc/ar6/wg3/Chapter07/fulltext.html \
--saving_path /content/ \
--method 'gensim'
print('\033[1;32m We have successfully finished running this cell.')
# Out:
#  We have successfully finished running this cell.

# %% [markdown]
# You can find the output of Keyword/key-phrases extraction here: **/content/gensim_keywords.csv**

# %% [markdown]
# A demonstration on how to look into CSV/HTML files on your right side of the notebbok:
#
# ![image.png](data:image/png;base64,...)

# %%
# WordCloud Generation
# !python /content/semanticClimate/wordCloud_Generation/SemanticClimate_wordcloud.py\
--file_path '/content/semanticClimate/wordCloud_Generation/'\
--saving_path '/content/'\
--Chapter_name 'Chapter07'

import cv2
from PIL import Image
from google.colab.patches import cv2_imshow
img = cv2.imread(f'/content/{chapter_no}_word_cloud.jpg', cv2.IMREAD_COLOR)
cv2_imshow(img)


#print('\033[1;32m We have successfully finished running this cell.')
# Out:
# Figure(1300x900)
# <PIL.Image.Image image mode=RGB size=1541x785>

# %% [markdown]
# ##HTML Markup and Annotation
# ![image.png](data:image/png;base64,...)
# **To Markup the HTML please click on the cell bellow..This also takes a min to run...**

# %%
# HTM markup using abbreviation dictionary + manual dictionary + keyword/phrases 
# !py4ami HTML --annotate\
--dict /content/wiki_hack/abb_chapter07.xml\
--inpath /content/semanticClimate/ipcc/ar6/wg3/Chapter07/fulltext.html\
--outpath /content/annotated_fulltext_Chapter07.html\
--color YELLOW

print('\033[1;32m We have successfully finished running this cell.')
# Out:
# ===========LOGGING 30 .. 10
# WARNING:pyami:
# ============== running pyami main ===============
# ['HTML', '--annotate', '--dict', '/content/wiki_hack/abb_chapter07.xml', '--inpath', '/content/semanticClimate/ipcc/ar6/wg3/Chapter07/fulltext.html', '--outpath', '/content/annotated_fulltext_Chapter07.html', '--color', 'YELLOW']
# WARNING:symbol.ini: environment variable $PYAMI_HOME not set, defaulting to bundled config.ini in /usr/local/lib/python3.7/dist-packages/py4ami
# WARNING:pyami:********** raw arglist ['HTML', '--annotate', '--dict', '/content/wiki_hack/abb_chapter07.xml', '--inpath', '/content/semanticClimate/ipcc/ar6/wg3/Chapter07/fulltext.html', '--outpath', '/content/annotated_fulltext_Chapter07.html', '--color', 'YELLOW']
# WARNING:pyami:PARSED_ARGS Namespace(annotate=True, apply=None, assert=None, color=['YELLOW'], combine=None, command='HTML', config=None, copy=None, debug=None, delete=None, dict=['/content/wiki_hack/abb_chapter07.xml'], examples=None, filter=None, flags=None, glob=None, inpath=['/content/semanticClimate/ipcc/ar6/wg3/Chapter07/fulltext.html'], languages=['en'], loglevel='info', maxbars=25, nosearch=False, outdir=None, outfile=None, outpath=['/content/annotated_fulltext_Chapter07.html'], patt=None, plot=True, proj=None, sect=None, split=None, version=False)
# WARNING:pyami:ARGS after substitution: {'version': False, 'apply': None, 'assert': None, 'combine': None, 'config': None, 'copy': None, 'debug': None, 'delete': None, 'dict': '/content/wiki_hack/abb_chapter07.xml', 'examples': None, 'filter': None, 'flags': None, 'glob': None, 'languages': 'en', 'loglevel': 'info', 'maxbars': 25, 'nosearch': False, 'outfile': None, 'patt': None, 'plot': True, 'proj': None, 'sect': None, 'split': None, 'command': 'HTML', 'annotate': True, 'color': 'YELLOW', 'inpath': '/content/semanticClimate/ipcc/ar6/wg3/Chapter07/fulltext.html', 'outpath': '/content/annotated_fulltext_Chapter07.html', 'outdir': None}
#  COMMAND: HTML {'version': False, 'apply': None, 'assert': None, 'combine': None, 'config': None, 'copy': None, 'debug': None, 'delete': None, 'dict': '/content/wiki_hack/abb_chapter07.xml', 'examples': None, 'filter': None, 'flags': None, 'glob': None, 'languages': 'en', 'loglevel': 'info', 'maxbars': 25, 'nosearch': False, 'outfile': None, 'patt': None, 'plot': True, 'proj': None, 'sect': None, 'split': None, 'command': 'HTML', 'annotate': True, 'color': 'YELLOW', 'inpath': '/content/semanticClimate/ipcc/ar6/wg3/Chapter07/fulltext.html', 'outpath': '/content/annotated_fulltext_Chapter07.html', 'outdir': None}
# WARNING:root:********** args for parse_and_process1 {'version': False, 'apply': None, 'assert': None, 'combine': None, 'config': None, 'copy': None, 'debug': None, 'delete': None, 'dict': '/content/wiki_hack/abb_chapter07.xml', 'examples': None, 'filter': None, 'flags': None, 'glob': None, 'languages': 'en', 'loglevel': 'info', 'maxbars': 25, 'nosearch': False, 'outfile': None, 'patt': None, 'plot': True, 'proj': None, 'sect': None, 'split': None, 'command': 'HTML', 'annotate': True, 'color': 'YELLOW', 'inpath': '/content/semanticClimate/ipcc/ar6/wg3/Chapter07/fulltext.html', 'outpath': '/content/annotated_fulltext_Chapter07.html', 'outdir': None}
# dictfile /content/wiki_hack/abb_chapter07.xml
# dictionary.entries 70
# duplicate terms not allowed greenhouse gas
# duplicate terms not allowed bioenergy with carbon capture and storage
# duplicate terms not allowed integrated assessment models
# duplicate terms not allowed carbon dioxide removal
# duplicate terms not allowed integrated assessment models
# entry_by_term 65
# title abb_chapter07
#  a_elems 170
# match_counter Counter({'Africa': 55, 'enteric fermentation': 13, 'integrated assessment models': 7, 'Latin America and Caribbean': 6, 'Integrated Assessment Model': 5, 'and reforestation': 5, 'Agriculture, Forestry and Other Land Uses': 4, 'National Greenhouse Gas Inventories': 4, 'rice production': 4, 'carbon dioxide removal': 3, 'greenhouse gas': 3, 'Sustainable intensification': 3, 'Clean Development Mechanism': 3, 'Sustainable Development Goals': 2, 'Nationally Determined Contributions': 2, 'business as usual': 2, 'animal waste management': 2, 'Climate Action Reserve': 2, 'EU Renewable Energy Directive': 2, 'Frequently Asked Questions': 1, 'bioenergy with carbon capture and storage': 1, 'volatile  organic  compounds': 1, 'Nationally  Dertermined  Contributions': 1, 'National  GHG  inventories': 1, 'and production processes, with existing': 1, 'Sustainable  Development  Goals': 1, 'National Greenhouse Gas Inventory': 1, 'IPCC  1996 guidelines': 1, 'Land Use, Land-Use Change, and Forestry': 1, 'Forestry and other land use': 1, 'Environmental Impact Assessments': 1, 'UN Environment Programme': 1, 'Bioenergy with Carbon Capture and Storage': 1, 'harvested wood products': 1, 'climate-smart agriculture': 1, 'National Dietary Guidelines': 1, 'Food  loss  and  waste': 1, 'Integrative land-use models': 1, 'bioenergy with CCS': 1, 'Illustrative  Mitigation  Pathways': 1, 'reduce  deforestation  and  forest degradation': 1, 'Nationally  Appropriate  Mitigation  Strategies': 1, 'Australia carbon credit units': 1, 'Global Environmental Facility': 1, 'Payment for Ecosystem Services': 1, 'impact evaluation': 1, 'National Adaptation Plans': 1, 'Community forest management': 1, 'Menominee Tribal Enterprises': 1, 'continuous forest inventories': 1, 'Forest  Sustainability  Council': 1, 'Programme  for  the Endorsement of Forest Certification': 1, 'Roundtable on Sustainable Palm Oil': 1, 'Plan  for  Prevention  and  Control  of Deforestation in the Legal Amazon': 1, 'Protected Areas': 1, 'Farmer Managed Natural Regeneration': 1, 'Climate  Action  Reserve': 1, 'Biomass Energy with Carbon Capture and Storage': 1, 'Shared Socioeconomic Pathway': 1, 'Climate  smart  agriculture': 1, 'climate  smart  cocoa': 1, 'Nature-based  solutions': 1})
# multidict {'Frequently Asked Questions': ['id28060_0'], 'Agriculture, Forestry and Other Land Uses': ['id28063_1', 'id220_0', 'id451_0', 'id1895_0'], 'bioenergy with carbon capture and storage': ['id28286_1'], 'carbon dioxide removal': ['id921_1', 'id9930_1', 'id24950_1'], 'greenhouse gas': ['id939_1', 'id1047_1', 'id1895_3'], 'volatile  organic  compounds': ['id1040_1'], 'integrated assessment models': ['id1212_1', 'id2438_1', 'id8963_1', 'id9530_1', 'id9813_1', 'id9930_4', 'id15593_1'], 'Nationally  Dertermined  Contributions': ['id1618_1'], 'National  GHG  inventories': ['id1656_1'], 'Sustainable Development Goals': ['id1686_1', 'id27600_1'], 'Integrated Assessment Model': ['id1905_1', 'id5680_1', 'id18814_1', 'id20238_4', 'id20777_1'], 'and production processes, with existing': ['id1974_1'], 'Sustainable  Development  Goals': ['id2108_1'], 'Nationally Determined Contributions': ['id2122_1', 'id22122_1'], 'National Greenhouse Gas Inventory': ['id2566_0'], 'IPCC  1996 guidelines': ['id2566_3'], 'Land Use, Land-Use Change, and Forestry': ['id2566_6'], 'Latin America and Caribbean': ['id4010_1', 'id11990_1', 'id12306_1', 'id20596_4', 'id20765_4', 'id21538_1'], 'National Greenhouse Gas Inventories': ['id4254_1', 'id4525_1', 'id5068_1', 'id5675_1'], 'Africa': ['id4539_1', 'id4618_0', 'id6180_1', 'id6260_1', 'id6264_4', 'id6272_1', 'id6279_1', 'id6284_1', 'id6305_1', 'id6852_1', 'id7056_1', 'id7067_1', 'id7442_1', 'id7480_1', 'id7628_1', 'id7636_1', 'id7812_1', 'id7982_1', 'id7986_1', 'id7986_4', 'id8185_1', 'id8326_1', 'id9772_1', 'id11545_1', 'id11565_1', 'id11972_1', 'id12031_1', 'id12287_1', 'id12503_1', 'id12509_1', 'id12976_1', 'id12976_4', 'id12997_1', 'id13041_1', 'id13181_1', 'id14370_1', 'id16818_1', 'id16960_1', 'id17455_1', 'id20596_1', 'id20765_1', 'id21538_4', 'id22355_1', 'id23707_1', 'id23900_1', 'id24158_1', 'id24768_1', 'id25188_1', 'id25394_1', 'id25394_4', 'id26978_1', 'id26978_4', 'id27174_1', 'id27350_4', 'id27350_7'], 'Forestry and other land use': ['id5933_1'], 'rice production': ['id5946_1', 'id7973_1', 'id20419_1', 'id20453_4'], 'enteric fermentation': ['id5955_1', 'id6120_1', 'id6264_1', 'id6264_7', 'id7846_1', 'id9961_1', 'id16052_1', 'id20257_4', 'id20416_1', 'id20435_1', 'id20453_1', 'id25220_1', 'id25925_1'], 'Environmental Impact Assessments': ['id7220_1'], 'UN Environment Programme': ['id8546_1'], 'Bioenergy with Carbon Capture and Storage': ['id8792_1'], 'Sustainable intensification': ['id9621_1', 'id25555_1', 'id25562_0'], 'and reforestation': ['id11755_1', 'id11950_1', 'id11995_1', 'id20288_1', 'id21984_1'], 'harvested wood products': ['id12218_1'], 'climate-smart agriculture': ['id17211_1'], 'business as usual': ['id18223_1', 'id24969_1'], 'National Dietary Guidelines': ['id19323_1'], 'Food  loss  and  waste': ['id19528_1'], 'Integrative land-use models': ['id20238_1'], 'bioenergy with CCS': ['id20257_1'], 'animal waste management': ['id20422_1', 'id20455_1'], 'Illustrative  Mitigation  Pathways': ['id21586_1'], 'Clean Development Mechanism': ['id21984_4', 'id22303_1', 'id22773_1'], 'reduce  deforestation  and  forest degradation': ['id22113_1'], 'Nationally  Appropriate  Mitigation  Strategies': ['id22113_4'], 'Climate Action Reserve': ['id22321_1', 'id25010_1'], 'Australia carbon credit units': ['id23235_1'], 'Global Environmental Facility': ['id23265_1'], 'Payment for Ecosystem Services': ['id23463_0'], 'impact evaluation': ['id23501_1'], 'National Adaptation Plans': ['id23515_1'], 'Community forest management': ['id23913_0'], 'Menominee Tribal Enterprises': ['id24109_1'], 'continuous forest inventories': ['id24109_4'], 'EU Renewable Energy Directive': ['id24169_1', 'id25773_1'], 'Forest  Sustainability  Council': ['id24318_1'], 'Programme  for  the Endorsement of Forest Certification': ['id24318_4'], 'Roundtable on Sustainable Palm Oil': ['id24341_1'], 'Plan  for  Prevention  and  Control  of Deforestation in the Legal Amazon': ['id24530_1'], 'Protected Areas': ['id24571_1'], 'Farmer Manag ...
# wrote /content/annotated_fulltext_Chapter07.html
# wrote /content/index.html
#  We have successfully finished running this cell.

# %% [markdown]
# You can find the ouput of HTML Markup and annotation chuck here: **/content/annotated_fulltext_Chapter07.html**

# %% [markdown]
# ![image.png](data:image/png;base64,...)
