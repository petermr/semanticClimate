# %% [markdown]
# <a href="https://colab.research.google.com/github/petermr/semanticClimate/blob/main/alis2024/sempub/alis_pygetpapers_bib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
bib_alis_df = pd.read_csv('https://raw.githubusercontent.com/petermr/semanticClimate/main/alis2024/sempub/europe_pmc.csv') # metadata from pygetpapers

# %%
bib_alis_df
# Out:
#      Unnamed: 0        id source        pmid        pmcid  \
# 0   PMC10280262  37346675    MED  37346675.0  PMC10280262
# 1   PMC11192941  38906886    MED  38906886.0  PMC11192941
# 2    PMC2663789  19381256    MED  19381256.0   PMC2663789
# 3   PMC10876301  38374955    MED  38374955.0  PMC10876301
# 4   PMC11087458  38730252    MED  38730252.0  PMC11087458
# ..          ...       ...    ...         ...          ...
# 95  PMC10862086  38357382    MED  38357382.0  PMC10862086
# 96  PMC11195943  38913621    MED  38913621.0  PMC11195943
# 97  PMC11078994  38719839    MED  38719839.0  PMC11078994
# 98  PMC10139678  37123781    MED  37123781.0  PMC10139678
# 99  PMC10753415  38090795    MED  38090795.0  PMC10753415
#
#                                   fullTextIdList  \
# 0   OrderedDict([('fullTextId', 'PMC10280262')])
# 1   OrderedDict([('fullTextId', 'PMC11192941')])
# 2    OrderedDict([('fullTextId', 'PMC2663789')])
# 3   OrderedDict([('fullTextId', 'PMC10876301')])
# ...

# %%
brief_metadata = bib_alis_df[['pmcid', "doi", "title", "authorString", "pubYear", "abstractText","isOpenAccess", "license"]] #selected columns
brief_metadata.to_csv('brief_metadata.csv')
